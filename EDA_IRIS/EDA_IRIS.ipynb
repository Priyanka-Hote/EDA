# %%
# importing the library

import numpy as np
import pandas as pd

# %%
# reading the dataset

df = pd.read_csv("/content/drive/MyDrive/machine_learining/iris_csv.csv")

# %%
# printing top 5 rows

df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
# getting the information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  150 non-null    float64
#  1   sepalwidth   150 non-null    float64
#  2   petallength  150 non-null    float64
#  3   petalwidth   150 non-null    float64
#  4   class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape #150 rows and 5 columns
# Out:
# (150, 5)

# %%
# print all the columns names

df.columns
# Out:
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class'], dtype='object')

# %%
#gives all the statastical info of the numerical columns
#. Any missing value or NaN value is automatically skipped. 

df.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
#Checking Missing Values

df.isnull().sum()
# Out:
# sepallength    0
# sepalwidth     0
# petallength    0
# petalwidth     0
# class          0
# dtype: int64

# %%
#Checking Duplicates  gives unique records of class column

duplicates = df.drop_duplicates(subset='class')
duplicates
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            class
# 0            5.1         3.5          1.4         0.2      Iris-setosa
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica

# %%
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.value_counts('class')
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# ## ***Data Visualization***
#
# ---

# %%
# importing the package

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# to visualize value_count function we use countplot

#sns.set_theme(style='darkgrid')
sns.dark_palette("seagreen")
sns.countplot(data=df,x='class')
plt.show()

# %% [markdown]
# # ***Relation between variables***
#
# ---

# %% [markdown]
# *We will see the relationship between the sepal length and sepal width and also between petal length and petal width.*

# %%
sns.scatterplot(x='sepallength',y='sepalwidth',data=df,hue='class')
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.show()

# %% [markdown]
# *   sepal length ▶ setosa < versicolor < virginca
# *   Sepal width  ▶ virginica < versicolor < setosa

# %%
sns.scatterplot(x='petallength',y='petalwidth',data=df,hue='class')
plt.show()
plt.legend()

# %% [markdown]
# * petal length,petal width ▶setosa < versicolor < virginica

# %% [markdown]
# ***Let’s plot all the column’s relationships using a pairplot. It can be used for multivariate analysis.***
#
# ---

# %%
sns.pairplot(data=df,hue='class',palette="husl")

# %% [markdown]
# ***Histograms***
#
# ---

# %% [markdown]
# Histograms allow seeing the distribution of data for various columns. It can be used for uni as well as bi-variate analysis.

# %%
from pandas.core.frame import Frequency
sns.histplot(x='petalwidth',data=df,stat='count')
plt.show()

# %%
#df['petalwidth'].value_counts()

# %% [markdown]
# **Handling Correlation**
#
# ---

# %% [markdown]
# * Complete correlation between two variables is expressed by either + 1 or -1.
# * When one variable increases as the other increases the correlation is positive;
# * when one decreases as the other increases it is negative. Complete absence of correlation is represented by 0.

# %%
df.corr()
# Out:
#              sepallength  sepalwidth  petallength  petalwidth
# sepallength     1.000000   -0.109369     0.871754    0.817954
# sepalwidth     -0.109369    1.000000    -0.420516   -0.356544
# petallength     0.871754   -0.420516     1.000000    0.962757
# petalwidth      0.817954   -0.356544     0.962757    1.000000

# %% [markdown]
# # ***HEATMAPS***
#
# ---

# %% [markdown]
# **same thing can be done with the help of heatmap**
#
# *The heatmap is a data visualization technique that is used to analyze the dataset as colors in two dimensions. Basically, it shows a correlation between all numerical variables in the dataset. In simpler terms, we can plot the above-found correlation using the heatmaps.*

# %%
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ***Box Plots***
#
# We can use boxplots to see how the categorical values distributed with other numerical values.
#
# ---

# %%
sns.boxplot(x='class',data=df,y='sepallength',palette='flare',orient='v')
# Out:
# <Axes: xlabel='class', ylabel='sepallength'>

# %%
def graph(Y):
  sns.boxplot(data=df,x='class',y=Y)
plt.figure(figsize=(15,15))
plt.subplot(221)
graph('sepallength')

plt.subplot(222)
graph('sepalwidth')

plt.subplot(223)
graph('petallength')

plt.subplot(224)
graph('petalwidth')
plt.show()

# %% [markdown]
# ***Handling Outliers***
#
# ---
#
#
#
# ---
